# %% [markdown]
# <font size = '5.5'> Predicting Pass Rusher Distance To The Quarterback With OLIZ: Offensive Linemen Immediate Zone </font>

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These may have been things we've known, but now they are ones we can quantify
